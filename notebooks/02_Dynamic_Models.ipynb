# %% [markdown]
# # 2) Dynamic Models
#
# **Purpose:** Derive from first-principles, the mathematical representation for physical systems that best describes its chracteristics and responses over time.
#
# **Learning Objectives:**
#
# - Understand and implement the underlying physics that best describes a given system using ODEs.
# - State the assumptions made to simplify the model.

# %%
import sympy as sp
import numpy as np

import control as ct
print("python-control", ct.__version__)
# Out:
# python-control 0.10.2

# %% [markdown]
# # 2.1 - Mechanical Systems

# %%
dir(ct)
# Out:
# ['ControlArgument',
#  'ControlDimension',
#  'ControlIndexError',
#  'ControlMIMONotImplemented',
#  'ControlNotImplemented',
#  'ControlPlot',
#  'ControlSlycot',
#  'DescribingFunctionNonlinearity',
#  'DescribingFunctionResponse',
#  'FRD',
#  'FrequencyResponseData',
#  'FrequencyResponseList',
#  'InputOutputSystem',
#  'InterconnectedSystem',
#  'LTI',
#  'LinearICSystem',
#  'NamedSignal',
#  'NonlinearIOSystem',
#  'NyquistResponseData',
#  'NyquistResponseList',
#  'OperatingPoint',
#  'PoleZeroData',
#  'PoleZeroList',
#  'StateSpace',
#  'TimeResponseData',
#  'TimeResponseList',
#  'TransferFunction',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'acker',
#  'append',
#  'augw',
#  'balanced_reduction',
#  'balred',
#  'bandwidth',
#  'bdalg',
#  'bdschur',
#  'bode',
#  'bode_plot',
#  'box_grid',
#  'c2d',
#  'canonical',
# ...
